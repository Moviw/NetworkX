# %% [markdown]
# # 创建图-NetworkX 内置图
#
# ## 参考文档
#
# NetworkX 主页：https://networkx.org
#
# networkx 创建图：https://networkx.org/documentation/stable/reference/generators.html

# %% [markdown]
# ## 导入工具包

# %%
import networkx as nx

# 数据可视化
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %% [markdown]
# ## 经典图结构

# %% [markdown]
# ### 1. 无向图

# %%
G = nx.complete_graph(7)
nx.draw(G)

# %%
# 全图连接数
G.size()
# Out:
# 21

# %% [markdown]
# ### 2. 全连接有向图

# %%
G = nx.complete_graph(7, nx.DiGraph())
nx.draw(G)

# %%
G.is_directed()
# Out:
# True

# %% [markdown]
# ### 3. 环状图

# %%
G = nx.cycle_graph(5)
nx.draw(G)

# %% [markdown]
# ### 4. 梯状图

# %%
G = nx.ladder_graph(5)
nx.draw(G)

# %% [markdown]
# ### 5. 线性串珠图

# %%
G = nx.path_graph(15)
nx.draw(G)

# %% [markdown]
# ### 6. 星状图

# %%
G = nx.star_graph(7)
nx.draw(G)

# %% [markdown]
# ### 7. 轮辐图

# %%
G = nx.wheel_graph(8)
nx.draw(G)

# %% [markdown]
# ### 8. 二项树

# %%
G = nx.binomial_tree(5)
nx.draw(G)

# %% [markdown]
# ## II. 栅格图

# %% [markdown]
# ### 1. 二维矩形网格图

# %%
G = nx.grid_2d_graph(3, 5)
nx.draw(G)

# %% [markdown]
# ### 2. 多维矩形网格图

# %%
G = nx.grid_graph(dim=(2, 3, 4))
nx.draw(G)

# %% [markdown]
# ### 3. 二维三角形网格图

# %%
G = nx.triangular_lattice_graph(2, 5)
nx.draw(G)

# %% [markdown]
# ### 4. 二维六边形蜂窝图

# %%
G = nx.hexagonal_lattice_graph(2, 3)
nx.draw(G)

# %% [markdown]
# ### 5. n 维超立方体图

# %%
G = nx.hypercube_graph(4)
nx.draw(G)

# %% [markdown]
# ## III. NetworkX 内置图

# %%
G = nx.diamond_graph()
nx.draw(G)

# %%
G = nx.bull_graph()
nx.draw(G)

# %%
G = nx.frucht_graph()
nx.draw(G)

# %%
G = nx.house_graph()
nx.draw(G)

# %%
G = nx.house_x_graph()
nx.draw(G)

# %%
G = nx.petersen_graph()
nx.draw(G)

# %%
G = nx.krackhardt_kite_graph()
nx.draw(G)

# %% [markdown]
# ## IV. 随机图

# %%
G = nx.erdos_renyi_graph(10, 0.5)
nx.draw(G)

# %% [markdown]
# ## V. 有向图

# %% [markdown]
# ### 1. 无标度有向图

# %%
G = nx.scale_free_graph(100)
nx.draw(G)

# %% [markdown]
# ## VI. 社交网络

# %%
# 空手道俱乐部数据集
G = nx.karate_club_graph()
nx.draw(G, with_labels=True)

# %%
G.nodes[5]["club"]
# Out:
# 'Mr. Hi'

# %%
G.nodes[9]["club"]
# Out:
# 'Officer'

# %%
# 雨果《悲惨世界》人物关系
G = nx.les_miserables_graph()
plt.figure(figsize=(12, 10))
pos = nx.spring_layout(G, seed=10)
nx.draw(G, pos, with_labels=True)

# %%
# Florentine families graph
G = nx.florentine_families_graph()
nx.draw(G, with_labels=True)

# %% [markdown]
# ## VII. 社群聚类图

# %%
G = nx.caveman_graph(4, 3)
nx.draw(G, with_labels=True)

# %% [markdown]
# ## VIII. 树

# %%
tree = nx.random_tree(n=10, seed=0)
print(nx.forest_str(tree, sources=[0]))
# Out:
# ╙── 0
#     ├── 3
#     └── 4
#         ├── 6
#         │   ├── 1
#         │   ├── 2
#         │   └── 7
#         │       └── 8
#         │           └── 5
#         └── 9
